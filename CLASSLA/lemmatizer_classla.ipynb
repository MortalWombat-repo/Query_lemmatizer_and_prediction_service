# %%
import sys
import os

# Add parent directory to sys.path
sys.path.append(os.path.abspath('..'))

# %%
import pandas as pd
from kategorije import reset_lozinke, cijena_paketa, problem_prijave, ostalo
import string
import classla
from IPython.display import display

# %%
len(reset_lozinke) , len(problem_prijave), len(cijena_paketa), len(ostalo)
# Out:
# (90, 90, 90, 90)

# %%
'''reset_lozinke DataFrame'''
reset_lozinke_labels = (
    ["reset_lozinke"] * len(reset_lozinke))

df_reset_lozinke = pd.DataFrame({
    "text": reset_lozinke,
    "label": reset_lozinke_labels
})

'''problem_prijave DataFrame'''
problem_prijave_labels = (
    ["problem_prijave"] * len(problem_prijave))


df_problem_prijave = pd.DataFrame({
    "text": problem_prijave,
    "label": problem_prijave_labels
})

'''cijena_paketa DataFrame'''
cijena_paketa_labels = (
    ["cijena_paketa"] * len(cijena_paketa))


df_cijena_paketa = pd.DataFrame({
    "text": cijena_paketa,
    "label": cijena_paketa_labels
})

'''ostalo DataFrame'''
ostalo_labels = (
    ["ostalo"] * len(cijena_paketa))


df_ostalo = pd.DataFrame({
    "text": ostalo,
    "label": ostalo_labels
})

display(df_reset_lozinke)
display(df_problem_prijave)
display(df_cijena_paketa)
display(df_ostalo)
# Out:
#                                                  text          label
# 0   Zaboravio sam lozinku, možete li mi pomoći da ...  reset_lozinke
# 1       Molim vas, trebam novu lozinku za svoj račun.  reset_lozinke
# 2   Ne sjećam se šifre, kako mogu promijeniti pris...  reset_lozinke
# 3   Kako da zamijenim svoju lozinku jer sam je zab...  reset_lozinke
# 4                Trebam link za reset lozinke, molim.  reset_lozinke
# ..                                                ...            ...
# 85     Pass ne radi ni nakon promjene – trebam pomoć.  reset_lozinke
# 86  Gdje mogu zatražiti novi pass ako se ne sjećam...  reset_lozinke
# 87       Molim upute za reset preko mobilnog uređaja.  reset_lozinke
# 88         Lozinka mi više ne radi, molim novu šifru.  reset_lozinke
# 89       Kako aktivirati novi pass nakon reset linka?  reset_lozinke
#
# [90 rows x 2 columns]
#                                                text            label
# 0               Ne mogu se prijaviti na svoj račun.  problem_prijave
# 1                         Imam problema s prijavom.  problem_prijave
# 2            Aplikacija me ne pušta da se prijavim.  problem_prijave
# 3         Unosim ispravne podatke, ali ne mogu ući.  problem_prijave
# 4         Pojavljuje mi se greška prilikom prijave.  problem_prijave
# ..                                              ...              ...
# 85     Prijava mi i dalje prikazuje stari korisnik.  problem_prijave
# 86        Ne mogu izabrati korisničko ime za login.  problem_prijave
# 87         Login ne radi samo u Chrome pregledniku.  problem_prijave
# 88           Ne mogu koristiti fingerprint prijavu.  problem_prijave
# 89  Otpali su svi moji login podaci nakon update‑a.  problem_prijave
#
# [90 rows x 2 columns]
#                                                  text          label
# 0                      Koja je cijena Premium paketa?  cijena_paketa
# 1                    Koliko košta mjesečna pretplata?  cijena_paketa
# 2                      Zanima me cijena vaših paketa.  cijena_paketa
# 3                 Koji su troškovi korištenja usluge?  cijena_paketa
# 4             Možete li mi reći koliko košta Premium?  cijena_paketa
# ..                                                ...            ...
# 85    Postoje li ograničenja unutar pojedinih paketa?  cijena_paketa
# 86             Imate li tabelu s opisima svih paketa?  cijena_paketa
# 87          Koji paket preporučujete za manje timove?  cijena_paketa
# 88  Na koji način su paketi prilagođeni različitim...  cijena_paketa
# 89  Možete li mi pomoći odabrati najbolji paket za...  cijena_paketa
#
# [90 rows x 2 columns]
#                                               text   label
# 0          Kako mogu promijeniti jezik aplikacije?  ostalo
# 1        Možete li mi pomoći oko postavki profila?  ostalo
# 2             Gdje mogu pronaći uvjete korištenja?  ostalo
# 3                        Kako obrisati svoj račun?  ostalo
# 4        Postoji li aplikacija za mobilne uređaje?  ostalo
# ..                                             ...     ...
# 85  Mogu li zakazati automatsko slanje izvještaja?  ostalo
# 86         Kako povezati račun s vanjskim alatima?  ostalo
# 87           Koje prečace podržava web aplikacija?  ostalo
# 88          Je li moguće pretraživati po oznakama?  ostalo
# 89             Kako izraditi predložak za zadatke?  ostalo
#
# [90 rows x 2 columns]

# %%
# clean text of punctuation
def clean_text(text):
    text = text.lower()
    text = ''.join([char for char in text if char not in string.punctuation])
    return text

# applying the cleaning function to a dataset
df_reset_lozinke['cleaned_text'] = df_reset_lozinke['text'].apply(lambda x: clean_text(x))
df_problem_prijave['cleaned_text'] = df_problem_prijave['text'].apply(lambda x: clean_text(x))
df_cijena_paketa['cleaned_text'] = df_cijena_paketa['text'].apply(lambda x: clean_text(x))
df_ostalo['cleaned_text'] = df_ostalo['text'].apply(lambda x: clean_text(x))


display(df_reset_lozinke)
display(df_problem_prijave)
display(df_cijena_paketa)
display(df_ostalo)
# Out:
#                                                  text          label  \
# 0   Zaboravio sam lozinku, možete li mi pomoći da ...  reset_lozinke
# 1       Molim vas, trebam novu lozinku za svoj račun.  reset_lozinke
# 2   Ne sjećam se šifre, kako mogu promijeniti pris...  reset_lozinke
# 3   Kako da zamijenim svoju lozinku jer sam je zab...  reset_lozinke
# 4                Trebam link za reset lozinke, molim.  reset_lozinke
# ..                                                ...            ...
# 85     Pass ne radi ni nakon promjene – trebam pomoć.  reset_lozinke
# 86  Gdje mogu zatražiti novi pass ako se ne sjećam...  reset_lozinke
# 87       Molim upute za reset preko mobilnog uređaja.  reset_lozinke
# 88         Lozinka mi više ne radi, molim novu šifru.  reset_lozinke
# 89       Kako aktivirati novi pass nakon reset linka?  reset_lozinke
#
#                                          cleaned_text
# 0   zaboravio sam lozinku možete li mi pomoći da j...
# 1         molim vas trebam novu lozinku za svoj račun
# 2   ne sjećam se šifre kako mogu promijeniti prist...
# 3   kako da zamijenim svoju lozinku jer sam je zab...
# 4                  trebam link za reset lozinke molim
# ..                                                ...
# 85      pass ne radi ni nakon promjene – trebam pomoć
# 86  gdje mogu zatražiti novi pass ako se ne sjećam...
# 87        molim upute za reset preko mobilnog uređaja
# 88           lozinka mi više ne radi molim novu šifru
# 89        kako aktivirati novi pass nakon reset linka
#
# [90 rows x 3 columns]
#                                                text            label  \
# 0               Ne mogu se prijaviti na svoj račun.  problem_prijave
# 1                         Imam problema s prijavom.  problem_prijave
# 2            Aplikacija me ne pušta da se prijavim.  problem_prijave
# 3         Unosim ispravne podatke, ali ne mogu ući.  problem_prijave
# 4         Pojavljuje mi se greška prilikom prijave.  problem_prijave
# ..                                              ...              ...
# 85     Prijava mi i dalje prikazuje stari korisnik.  problem_prijave
# 86        Ne mogu izabrati korisničko ime za login.  problem_prijave
# 87         Login ne radi samo u Chrome pregledniku.  problem_prijave
# 88           Ne mogu koristiti fingerprint prijavu.  problem_prijave
# 89  Otpali su svi moji login podaci nakon update‑a.  problem_prijave
#
#                                       cleaned_text
# 0               ne mogu se prijaviti na svoj račun
# 1                         imam problema s prijavom
# 2            aplikacija me ne pušta da se prijavim
# 3          unosim ispravne podatke ali ne mogu ući
# 4         pojavljuje mi se greška prilikom prijave
# ..                                             ...
# 85     prijava mi i dalje prikazuje stari korisnik
# 86        ne mogu izabrati korisničko ime za login
# 87         login ne radi samo u chrome pregledniku
# 88           ne mogu koristiti fingerprint prijavu
# 89  otpali su svi moji login podaci nakon update‑a
#
# [90 rows x 3 columns]
#                                                  text          label  \
# 0                      Koja je cijena Premium paketa?  cijena_paketa
# 1                    Koliko košta mjesečna pretplata?  cijena_paketa
# 2                      Zanima me cijena vaših paketa.  cijena_paketa
# 3                 Koji su troškovi korištenja usluge?  cijena_paketa
# 4             Možete li mi reći koliko košta Premium?  cijena_paketa
# ..                                                ...            ...
# 85    Postoje li ograničenja unutar pojedinih paketa?  cijena_paketa
# 86             Imate li tabelu s opisima svih paketa?  cijena_paketa
# 87          Koji paket preporučujete za manje timove?  cijena_paketa
# 88  Na koji način su paketi prilagođeni različitim...  cijena_paketa
# 89  Možete li mi pomoći odabrati najbolji paket za...  cijena_paketa
#
#                                          cleaned_text
# 0                       koja je cijena premium paketa
# 1                     koliko košta mjesečna pretplata
# 2                       zanima me cijena vaših paketa
# 3                  koji su troškovi korištenja usluge
# 4              možete li mi reći koliko košta premium
# ..                                                ...
# 85     postoje li ograničenja unutar pojedinih paketa
# 86              imate li tabelu s opisima svih paketa
# 87           koji paket preporučujete za manje timove
# 88  na koji način su paketi prilagođeni različitim...
# 89  možete li mi pomoći odabrati najbolji paket za...
#
# [90 rows x 3 columns]
#                                               text   label  \
# 0          Kako mogu promijeniti jezik aplikacije?  ostalo
# 1        Možete li mi pomoći oko postavki profila?  ostalo
# 2             Gdje mogu pronaći uvjete korištenja?  ostalo
# 3                        Kako obrisati svoj račun?  ostalo
# 4        Postoji li aplikacija za mobilne uređaje?  ostalo
# ..                                             ...     ...
# 85  Mogu li zakazati automatsko slanje izvještaja?  ostalo
# 86         Kako povezati račun s vanjskim alatima?  ostalo
# 87           Koje prečace podržava web aplikacija?  ostalo
# 88          Je li moguće pretraživati po oznakama?  ostalo
# 89             Kako izraditi predložak za zadatke?  ostalo
#
#                                      cleaned_text
# 0          kako mogu promijeniti jezik aplikacije
# 1        možete li mi pomoći oko postavki profila
# 2             gdje mogu pronaći uvjete korištenja
# 3                        kako obrisati svoj račun
# 4        postoji li aplikacija za mobilne uređaje
# ..                                            ...
# 85  mogu li zakazati automatsko slanje izvještaja
# 86         kako povezati račun s vanjskim alatima
# 87           koje prečace podržava web aplikacija
# 88          je li moguće pretraživati po oznakama
# 89             kako izraditi predložak za zadatke
#
# [90 rows x 3 columns]

# %%
classla.download('hr')
nlp = classla.Pipeline('hr', processors='tokenize,pos,lemma')

def classla_lemmatize_croatian(text):
    doc = nlp(text)
    return ' '.join([word.lemma for sent in doc.sentences for word in sent.words])

df_reset_lozinke['lemmatized_text'] = df_reset_lozinke['cleaned_text'].apply(classla_lemmatize_croatian)
df_problem_prijave['lemmatized_text'] = df_problem_prijave['cleaned_text'].apply(classla_lemmatize_croatian)
df_cijena_paketa['lemmatized_text'] = df_cijena_paketa['cleaned_text'].apply(classla_lemmatize_croatian)
df_ostalo['lemmatized_text'] = df_ostalo['cleaned_text'].apply(classla_lemmatize_croatian)

display(df_reset_lozinke)
display(df_problem_prijave)
display(df_cijena_paketa)
display(df_ostalo)
# Out:
# Downloading https://raw.githubusercontent.com/clarinsi/classla-resources/main/resources_2.2.json: 15.9kB [00:00, 28.4MB/s]
# 2025-07-13 21:31:25 INFO: Downloading these customized packages for language: hr (Croatian)...
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# | pos       | standard |
# | lemma     | standard |
# | depparse  | standard |
# | ner       | standard |
# | pretrain  | standard |
# ========================
#
# 2025-07-13 21:31:25 INFO: File exists: /home/ikar/classla_resources/hr/pos/standard.pt.
# 2025-07-13 21:31:26 INFO: File exists: /home/ikar/classla_resources/hr/lemma/standard.pt.
# 2025-07-13 21:31:27 INFO: File exists: /home/ikar/classla_resources/hr/depparse/standard.pt.
# 2025-07-13 21:31:27 INFO: File exists: /home/ikar/classla_resources/hr/ner/standard.pt.
# 2025-07-13 21:31:27 INFO: File exists: /home/ikar/classla_resources/hr/pretrain/standard.pt.
# 2025-07-13 21:31:27 INFO: Finished downloading models and saved to /home/ikar/classla_resources.
# 2025-07-13 21:31:27 INFO: Loading these models for language: hr (Croatian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | standard |
# | pos       | standard |
# | lemma     | standard |
# ========================
#
# 2025-07-13 21:31:27 INFO: Use device: cpu
# 2025-07-13 21:31:27 INFO: Loading: tokenize
# 2025-07-13 21:31:27 INFO: Loading: pos
# 2025-07-13 21:31:30 INFO: Loading: lemma
# 2025-07-13 21:31:39 INFO: Done loading processors!
#                                                  text          label  \
# 0   Zaboravio sam lozinku, možete li mi pomoći da ...  reset_lozinke
# 1       Molim vas, trebam novu lozinku za svoj račun.  reset_lozinke
# 2   Ne sjećam se šifre, kako mogu promijeniti pris...  reset_lozinke
# 3   Kako da zamijenim svoju lozinku jer sam je zab...  reset_lozinke
# 4                Trebam link za reset lozinke, molim.  reset_lozinke
# ..                                                ...            ...
# 85     Pass ne radi ni nakon promjene – trebam pomoć.  reset_lozinke
# 86  Gdje mogu zatražiti novi pass ako se ne sjećam...  reset_lozinke
# 87       Molim upute za reset preko mobilnog uređaja.  reset_lozinke
# 88         Lozinka mi više ne radi, molim novu šifru.  reset_lozinke
# 89       Kako aktivirati novi pass nakon reset linka?  reset_lozinke
#
#                                          cleaned_text  \
# 0   zaboravio sam lozinku možete li mi pomoći da j...
# 1         molim vas trebam novu lozinku za svoj račun
# 2   ne sjećam se šifre kako mogu promijeniti prist...
# 3   kako da zamijenim svoju lozinku jer sam je zab...
# 4                  trebam link za reset lozinke molim
# ..                                                ...
# 85      pass ne radi ni nakon promjene – trebam pomoć
# 86  gdje mogu zatražiti novi pass ako se ne sjećam...
# 87        molim upute za reset preko mobilnog uređaja
# 88           lozinka mi više ne radi molim novu šifru
# 89        kako aktivirati novi pass nakon reset linka
#
#                                       lemmatized_text
# 0   zaboraviti biti lozinka moći li ja pomoći da o...
# 1         moliti vi trebati nov lozinka za svoj račun
# 2   ne sjećati sebe šifra kako moći promijeniti pr...
# 3   kako da zamijeniti svoj lozinka jer biti on za...
# 4                trebati link za reset lozinka moliti
# ..                                                ...
# 85   pass ne raditi ni nakon promjena – trebati pomoć
# 86  gdje moći zatražiti nov pass ako sebe ne sjeća...
# 87         moliti uputa za reset preko mobilan uređaj
# 88         lozinka ja više ne raditi moliti nov šifra
# 89          kako aktivirati nov pass nakon reset link
#
# [90 rows x 4 columns]
#                                                text            label  \
# 0               Ne mogu se prijaviti na svoj račun.  problem_prijave
# 1                         Imam problema s prijavom.  problem_prijave
# 2            Aplikacija me ne pušta da se prijavim.  problem_prijave
# 3         Unosim ispravne podatke, ali ne mogu ući.  problem_prijave
# 4         Pojavljuje mi se greška prilikom prijave.  problem_prijave
# ..                                              ...              ...
# 85     Prijava mi i dalje prikazuje stari korisnik.  problem_prijave
# 86        Ne mogu izabrati korisničko ime za login.  problem_prijave
# 87         Login ne radi samo u Chrome pregledniku.  problem_prijave
# 88           Ne mogu koristiti fingerprint prijavu.  problem_prijave
# 89  Otpali su svi moji login podaci nakon update‑a.  problem_prijave
#
#                                       cleaned_text  \
# 0               ne mogu se prijaviti na svoj račun
# 1                         imam problema s prijavom
# 2            aplikacija me ne pušta da se prijavim
# 3          unosim ispravne podatke ali ne mogu ući
# 4         pojavljuje mi se greška prilikom prijave
# ..                                             ...
# 85     prijava mi i dalje prikazuje stari korisnik
# 86        ne mogu izabrati korisničko ime za login
# 87         login ne radi samo u chrome pregledniku
# 88           ne mogu koristiti fingerprint prijavu
# 89  otpali su svi moji login podaci nakon update‑a
#
#                                       lemmatized_text
# 0                ne moći sebe prijaviti na svoj račun
# 1                            imati problem sa prijava
# 2          aplikacija ja ne puštati da sebe prijaviti
# 3            unositi ispravan podatak ali ne moći ući
# 4        pojavljivati ja sebe greška prilikom prijava
# ..                                                ...
# 85      prijava ja i daleko prikazivati star korisnik
# 86           ne moći izabrati korisnički ime za login
# 87           login ne raditi samo u chrome preglednik
# 88              ne moći koristiti fingerprint prijava
# 89  otpasti biti sav moj login podatak nakon updat...
#
# [90 rows x 4 columns]
#                                                  text          label  \
# 0                      Koja je cijena Premium paketa?  cijena_paketa
# 1                    Koliko košta mjesečna pretplata?  cijena_paketa
# 2                      Zanima me cijena vaših paketa.  cijena_paketa
# 3                 Koji su troškovi korištenja usluge?  cijena_paketa
# 4             Možete li mi reći koliko košta Premium?  cijena_paketa
# ..                                                ...            ...
# 85    Postoje li ograničenja unutar pojedinih paketa?  cijena_paketa
# 86             Imate li tabelu s opisima svih paketa?  cijena_paketa
# 87          Koji paket preporučujete za manje timove?  cijena_paketa
# 88  Na koji način su paketi prilagođeni različitim...  cijena_paketa
# 89  Možete li mi pomoći odabrati najbolji paket za...  cijena_paketa
#
#                                          cleaned_text  \
# 0                       koja je cijena premium paketa
# 1                     koliko košta mjesečna pretplata
# 2                       zanima me cijena vaših paketa
# 3                  koji su troškovi korištenja usluge
# 4              možete li mi reći koliko košta premium
# ..                                                ...
# 85     postoje li ograničenja unutar pojedinih paketa
# 86              imate li tabelu s opisima svih paketa
# 87           koji paket preporučujete za manje timove
# 88  na koji način su paketi prilagođeni različitim...
# 89  možete li mi pomoći odabrati najbolji paket za...
#
#                                       lemmatized_text
# 0                      koji biti cijena Premium paket
# 1                   koliko koštati mjesečan pretplata
# 2                        zanimati ja cijena vaš paket
# 3                  koji biti trošak korištenje usluga
# 4              moći li ja reći koliko koštati Premium
# ..                                                ...
# 85     postojati li ograničenje unutar pojedini paket
# 86                  imati li tabela sa opis sav paket
# 87               koji paket preporučivati za mali tim
# 88  na koji način biti paket prilagoditi različit ...
# 89  moći li ja pomoći odabrati dobar paket za moj ...
#
# [90 rows x 4 columns]
#                                               text   label  \
# 0          Kako mogu promijeniti jezik aplikacije?  ostalo
# 1        Možete li mi pomoći oko postavki profila?  ostalo
# 2             Gdje mogu pronaći uvjete korištenja?  ostalo
# 3                        Kako obrisati svoj račun?  ostalo
# 4        Postoji li aplikacija za mobilne uređaje?  ostalo
# ..                                             ...     ...
# 85  Mogu li zakazati automatsko slanje izvještaja?  ostalo
# 86         Kako povezati račun s vanjskim alatima?  ostalo
# 87           Koje prečace podržava web aplikacija?  ostalo
# 88          Je li moguće pretraživati po oznakama?  ostalo
# 89             Kako izraditi predložak za zadatke?  ostalo
#
#                                      cleaned_text  \
# 0          kako mogu promijeniti jezik aplikacije
# 1        možete li mi pomoći oko postavki profila
# 2             gdje mogu pronaći uvjete korištenja
# 3                        kako obrisati svoj račun
# 4        postoji li aplikacija za mobilne uređaje
# ..                                            ...
# 85  mogu li zakazati automatsko slanje izvještaja
# 86         kako povezati račun s vanjskim alatima
# 87           koje prečace podržava web aplikacija
# 88          je li moguće pretraživati po oznakama
# 89             kako izraditi predložak za zadatke
#
#                                  lemmatized_text
# 0         kako moći promijeniti jezik aplikacija
# 1          moći li ja pomoći oko postavka profil
# 2             gdje moći pronaći uvjet korištenje
# 3                       kako obrisati svoj račun
# 4      postojati li aplikacija za mobilan uređaj
# ..                                           ...
# 85  moći li zakazati automatski slanje izvještaj
# 86           kako povezati račun sa vanjski alat
# 87         koji prečac podržavati web aplikacija
# 88          biti li moguć pretraživati po oznaka
# 89            kako izraditi predložak za zadatak
#
# [90 rows x 4 columns]

# %%
# Assuming you already have df_reset_lozinke
reset_lozinke_lemma = df_reset_lozinke['lemmatized_text'].tolist()
problem_prijave_lemma = df_problem_prijave['lemmatized_text'].tolist()
cijena_paketa_lemma = df_cijena_paketa['lemmatized_text'].tolist()
ostalo_lemma = df_ostalo['lemmatized_text'].tolist()

# Write to a new Python file
with open("kategorije_lemmatized_classla.py", "w", encoding="utf-8") as f:
    f.write("reset_lozinke = [\n")
    for text in reset_lozinke_lemma:
        escaped = text.replace("\\", "\\\\").replace('"', '\\"')  # escape special chars
        f.write(f'    "{escaped}",\n')
    f.write("]\n")

    f.write("problem_prijave = [\n")
    for text in problem_prijave_lemma:
        escaped = text.replace("\\", "\\\\").replace('"', '\\"')  # escape special chars
        f.write(f'    "{escaped}",\n')
    f.write("]\n")

    f.write("cijena_paketa = [\n")
    for text in cijena_paketa_lemma:
        escaped = text.replace("\\", "\\\\").replace('"', '\\"')  # escape special chars
        f.write(f'    "{escaped}",\n')
    f.write("]\n")

    f.write("ostalo = [\n")
    for text in ostalo_lemma:
        escaped = text.replace("\\", "\\\\").replace('"', '\\"')  # escape special chars
        f.write(f'    "{escaped}",\n')
    f.write("]\n")
